# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import datetime
from sqlalchemy import create_engine
from pyathena import connect

# show complete dataframe content
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.set_option('display.max_colwidth', -1)
# show plots in the notebook
# %matplotlib inline

# %%
## set up Athena connection
import configparser


config = configparser.ConfigParser()
config.read('/Users/xyin/.aws/credentials')

aws = {key: value for key, value in config.items('default')}

conn = connect(aws_access_key_id=aws['aws_access_key_id'],
                 aws_secret_access_key=aws['aws_secret_access_key'],
                 aws_session_token=aws['aws_session_token'],
                 s3_staging_dir='s3://awsdatasrv-athena-staging/',
                 region_name='us-east-1')

# %%
import json

# %% [markdown]
# # step 1: import the json of clustering outcome

# %%
with open('../../mmr_lookup_profile/metadata/google_output/location_clustering/clusterout_user10_google.json','r') as file:
    google = json.loads(file.read())

# %%
import re

# %% [markdown]
# # step 2: import cluster result

# %%
clusters = pd.read_csv('../metadata/clusterout_user10.csv',sep=',',header=0)

# %%
clusters.head(3)
# Out:
#      lat3   long3  cluster_id
# 0  38.347 -77.488  6
# 1  33.620 -84.499  1
# 2  40.886 -81.566  6

# %%
auctionlike = clusters.loc[clusters.cluster_id!=4].copy()

# %%
auctionlike.dtypes
# Out:
# lat3          float64
# long3         float64
# cluster_id    int64
# dtype: object

# %% [markdown]
# # step 3: create georgia geofence

# %%
georgia = [
    (34.992756,-85.625226),
    (30.721736,-84.926279),
    (30.589405,-81.492173),
    (32.016373,-80.817001),
    (34.992871,-83.101132),
    (34.992756,-85.625226)
]

# %%
import folium
from folium import plugins


import gmplot
from gmplot import gmplot2

# %%
m = folium.Map([33.909508, -84.355094], zoom_start=5)
folium.PolyLine(georgia).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # step 4: find out the georgia clusters

# %%
auctionlike_latlong = [(lat,long) for lat,long in zip(auctionlike.lat3,auctionlike.long3)]

# %%
auctionlike_latlong[:5]
# Out:
# [(38.347, -77.488),
#  (33.62, -84.499),
#  (40.885999999999996, -81.566),
#  (33.865, -117.84100000000001),
#  (34.202, -118.402)]

# %%
from shapely.geometry import Point
from shapely.geometry.polygon import Polygon

# %%
polygon = Polygon(georgia)

# %%
auctionlike_georgia = [record for record in auctionlike_latlong if polygon.contains(Point(record[0],record[1]))]

# %%
len(auctionlike_georgia)
# Out:
# 212

# %%
m = folium.Map([33.909508, -84.355094], zoom_start=6)

# mark all cluster locations
for location in auctionlike_georgia:
    folium.Marker(
        [location[0], location[1]],
#         popup=folium.Popup(row['cluster_id'],parse_html=True),
        icon=folium.Icon(color='red')
    ).add_to(m)
    
m.save('../metadata/test.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # step 5: find the corresponding nearby business found in google

# %%
auctionlike_georgia_dict_raw = {
    str(round(record[0],3))+','+str(round(record[1],3)):google[str(round(record[0],3))+','+str(round(record[1],3))][0]
    for record in auctionlike_georgia if (len(google[str(round(record[0],3))+','+str(round(record[1],3))])>0)
}

# %%
auctionlike_georgia_dict = {
    key:{
        'name':value['name'],
        'latlong':"{},{}".format(value['geometry']['location']['lat'],value['geometry']['location']['lng']),
        'address':value['formatted_address']
    }
    for key,value in auctionlike_georgia_dict_raw.items() if bool(re.match('.*auto.*auction.*',value['name'].lower()))
}

# %%
auctionlike_georgia_dict
# Out:
# {'32.652,-83.648': {'name': 'VEMO Auto Auctions',
#   'latlong': '32.6510009,-83.64865979999999',
#   'address': '441 Dunbar Rd, Warner Robins, GA 31093, USA'},
#  '34.234,-83.898': {'name': 'Oakwoods Arrow Auto Auction',
#   'latlong': '34.2334842,-83.8984545',
#   'address': '4712 Flat Creek Rd, Oakwood, GA 30566, USA'},
#  '33.629,-84.305': {'name': 'AutoNation Auto Auction Atlanta',
#   'latlong': '33.6303677,-84.3080105',
#   'address': '2491 Old Anvil Block Rd, Ellenwood, GA 30294, USA'},
#  '34.259,-83.489': {'name': 'Georgia - Carolina Auto Auction',
#   'latlong': '34.2589807,-83.4892078',
#   'address': '884 E Ridgeway Rd, Commerce, GA 30529, USA'},
#  '32.651,-83.649': {'name': 'VEMO Auto Auctions',
#   'latlong': '32.6510009,-83.64865979999999',
#   'address': '441 Dunbar Rd, Warner Robins, GA 31093, USA'},
#  '34.233,-83.899': {'name': 'Oakwoods Arrow Auto Auction',
#   'latlong': '34.2334842,-83.8984545',
#   'address': '4712 Flat Creek Rd, Oakwood, GA 30566, USA'},
#  '33.933,-84.17': {'name': 'Auto Auctions',
#   'latlong': '33.954841,-84.198661',
#   'address': '2775 Northwoods Pkwy, Norcross, GA 30071, USA'},
#  '32.085,-81.197': {'name': 'Southeastern Auto Auction',
#   'latlong': '32.0867058,-81.1966333',
#   'address': '1712 Dean Forest Rd, Savannah, GA 31408, USA'},
#  '33.63,-84.306': {'name': 'AutoNation Auto Auction Atlanta',
#   'latlong': '33.6303677,-84.3080105',
#   'address': '2491 Old Anvil Block Rd, Ellenwood, GA 30294, USA'},
#  '33.944,-83.507': {'name': 'Athens Auto Auction',
#   'latlong': '33.9443602,-83.507815',
#   'address': '5050 Atlanta Hwy, Bogart, GA 30622, USA'},
#  '34.234,-83.899': {'name': 'Oakwoods Arrow Auto Auction',
#   'latlong': '34.2334842,-83.8984545',
#   'address': '4712 Flat Creek Rd, Oakwood, GA 30566, USA'},
#  '33.944,-83.506': {'name': 'Athens Auto Auction',
#   'latlong': '33.9443602,-83.507815',
#   'address': '5050 Atlanta Hwy, Bogart, GA 30622, USA'},
#  '33.928,-84.351': {'name': 'Auto Auction Services Corporation',
#   'latlong': '33.9405501,-84.361437',
#   'address': '50 Glenlake Pkwy NE, Atlanta, GA 30328, USA'},
#  '31.509,-84.116': {'name': 'Albany Auto Auction',
#   'latlong': '31.5092048,-84.1166549',
#   'address': '1421 Liberty Expy, Albany, GA 31705, USA'},
#  '33.484,-81.946': {'name': 'Augusta Auto Auction',
#   'latlong': '33.4827023,-81.9460647',
#   'address': '395 Hamburg Rd, North Augusta, SC 29841, USA'},
#  '33.484,-81.947': {'name': 'Augusta Auto Auction',
#   'latlong': '33.4827023,-81.9460647',
#   'address': '395 Hamburg Rd, North Augusta, SC 29841, USA'},
#  '32.651,-83.648': {'name': 'VEMO Auto Auctions',
#   'latlong': '32.6510009,-83.64865979999999',
#   'address': '441 Dunbar Rd, Warner Robins, GA 31093, USA'},
#  '34.234,-83.897': {'name': 'Oakwoods Arrow Auto Auction',
#   'latlong': '34.2334842,-83.8984545',
#   'address': '4712 Flat Creek Rd, Oakwood, GA 30566, USA'},
#  '33.631,-84.307': {'name': 'AutoNation Auto Auction Atlanta',
#   'latlong': '33.6303677,-84.3080105',
#   'address': '2491 Old Anvil Block Rd, Ellenwood, GA 30294, USA'},
#  '33.932,-84.167': {'name': 'Auto Auctions',
#   'latlong': '33.954841,-84.198661',
#   'address': '2775 Northwoods Pkwy, Norcross, GA 30071, USA'},
#  '33.932,-84.168': {'name': 'Auto Auctions',
#   'latlong': '33.954841,-84.198661',
#   'address': '2775 Northwoods Pkwy, Norcross, GA 30071, USA'},
#  '33.482,-81.947': {'name': 'Augusta Auto Auction',
#   'latlong': '33.4827023,-81.9460647',
#   'address': '395 Hamburg Rd, North Augusta, SC 29841, USA'},
#  '33.483,-81.946': {'name': 'Augusta Auto Auction',
#   'latlong': '33.4827023,-81.9460647',
#   'address': '395 Hamburg Rd, North Augusta, SC 29841, USA'},
#  '33.483,-81.947': {'name': 'Augusta Auto Auction',
#   'latlong': '33.4827023,-81.9460647',
#   'address': '395 Hamburg Rd, North Augusta, SC 29841, USA'},
#  '33.933,-84.168': {'name': 'Auto Auctions',
#   'latlong': '33.954841,-84.198661',
#   'address': '2775 Northwoods Pkwy, Norcross, GA 30071, USA'},
#  '32.087,-81.194': {'name': 'Southeastern Auto Auction',
#   'latlong': '32.0867058,-81.1966333',
#   'address': '1712 Dean Forest Rd, Savannah, GA 31408, USA'},
#  '33.944,-83.508': {'name': 'Athens Auto Auction',
#   'latlong': '33.9443602,-83.507815',
#   'address': '5050 Atlanta Hwy, Bogart, GA 30622, USA'},
#  '33.944,-83.509': {'name': 'Athens Auto Auction',
#   'latlong': '33.9443602,-83.507815',
#   'address': '5050 Atlanta Hwy, Bogart, GA 30622, USA'},
#  '33.933,-84.167': {'name': 'Auto Auctions',
#   'latlong': '33.954841,-84.198661',
#   'address': '2775 Northwoods Pkwy, Norcross, GA 30071, USA'},
#  '34.259,-83.49': {'name': 'Georgia - Carolina Auto Auction',
#   'latlong': '34.2589807,-83.4892078',
#   'address': '884 E Ridgeway Rd, Commerce, GA 30529, USA'},
#  '34.233,-83.897': {'name': 'Oakwoods Arrow Auto Auction',
#   'latlong': '34.2334842,-83.8984545',
#   'address': '4712 Flat Creek Rd, Oakwood, GA 30566, USA'},
#  '34.741,-84.422': {'name': 'Hwy 515 Auto Auction',
#   'latlong': '34.741224,-84.42113300000001',
#   'address': '107 Whitepath Rd, Ellijay, GA 30540, USA'},
#  '32.086,-81.196': {'name': 'Southeastern Auto Auction',
#   'latlong': '32.0867058,-81.1966333',
#   'address': '1712 Dean Forest Rd, Savannah, GA 31408, USA'},
#  '32.086,-81.197': {'name': 'Southeastern Auto Auction',
#   'latlong': '32.0867058,-81.1966333',
#   'address': '1712 Dean Forest Rd, Savannah, GA 31408, USA'},
#  '33.63,-84.305': {'name': 'AutoNation Auto Auction Atlanta',
#   'latlong': '33.6303677,-84.3080105',
#   'address': '2491 Old Anvil Block Rd, Ellenwood, GA 30294, USA'},
#  '33.631,-84.306': {'name': 'AutoNation Auto Auction Atlanta',
#   'latlong': '33.6303677,-84.3080105',
#   'address': '2491 Old Anvil Block Rd, Ellenwood, GA 30294, USA'},
#  '33.933,-84.169': {'name': 'Auto Auctions',
#   'latlong': '33.954841,-84.198661',
#   'address': '2775 Northwoods Pkwy, Norcross, GA 30071, USA'},
#  '32.087,-81.196': {'name': 'Southeastern Auto Auction',
#   'latlong': '32.0867058,-81.1966333',
#   'address': '1712 Dean Forest Rd, Savannah, GA 31408, USA'},
#  '32.087,-81.195': {'name': 'Southeastern Auto Auction',
#   'latlong': '32.0867058,-81.1966333',
#   'address': '1712 Dean Forest Rd, Savannah, GA 31408, USA'},
#  '32.087,-81.197': {'name': 'Southeastern Auto Auction',
#   'latlong': '32.0867058,-81.1966333',
#   'address': '1712 Dean Forest Rd, Savannah, GA 31408, USA'},
#  '34.233,-83.898': {'name': 'Oakwoods Arrow Auto Auction',
#   'latlong': '34.2334842,-83.8984545',
#   'address': '4712 Flat Creek Rd, Oakwood, GA 30566, USA'}}

# %%
auctions_new = set([
    value['name']+'|'+value['latlong']+'|'+value['address'].replace(', USA','')
    for value in auctionlike_georgia_dict.values()
])

# %%
auctions_new
# Out:
# {'Albany Auto Auction|31.5092048,-84.1166549|1421 Liberty Expy, Albany, GA 31705',
#  'Athens Auto Auction|33.9443602,-83.507815|5050 Atlanta Hwy, Bogart, GA 30622',
#  'Augusta Auto Auction|33.4827023,-81.9460647|395 Hamburg Rd, North Augusta, SC 29841',
#  'Auto Auction Services Corporation|33.9405501,-84.361437|50 Glenlake Pkwy NE, Atlanta, GA 30328',
#  'Auto Auctions|33.954841,-84.198661|2775 Northwoods Pkwy, Norcross, GA 30071',
#  'AutoNation Auto Auction Atlanta|33.6303677,-84.3080105|2491 Old Anvil Block Rd, Ellenwood, GA 30294',
#  'Georgia - Carolina Auto Auction|34.2589807,-83.4892078|884 E Ridgeway Rd, Commerce, GA 30529',
#  'Hwy 515 Auto Auction|34.741224,-84.42113300000001|107 Whitepath Rd, Ellijay, GA 30540',
#  'Oakwoods Arrow Auto Auction|34.2334842,-83.8984545|4712 Flat Creek Rd, Oakwood, GA 30566',
#  'Southeastern Auto Auction|32.0867058,-81.1966333|1712 Dean Forest Rd, Savannah, GA 31408',
#  'VEMO Auto Auctions|32.6510009,-83.64865979999999|441 Dunbar Rd, Warner Robins, GA 31093'}

# %%
m = folium.Map([33.909508, -84.355094], zoom_start=6)

# mark all cluster locations
for location in auctionlike_georgia:
    folium.Marker(
        [location[0], location[1]],
        icon=folium.Icon(color='red')
    ).add_to(m)

# mark all the auctions found via google
for location in auctions_new:
      folium.Marker(
        [float(location.split('|')[1].split(',')[0]), float(location.split('|')[1].split(',')[1])],
        popup=folium.Popup(location.split('|')[0],parse_html=True),
        icon=folium.Icon(color='green')
    ).add_to(m)  

m.save('../metadata/test.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # step 6: import known list of auction locations

# %%
query = '''
SELECT
  location_cat,
  location_name,
  addr,
  lat,
  long
FROM default.ds_geo_poi
WHERE location_cat IN ('manheim','competitor auctions');
'''

auctions = pd.read_sql(query, conn)
auctions.lat = auctions.lat.astype(float)
auctions.long = auctions.long.astype(float)

# %%
auctions.head(3)
# Out:
#           location_cat                      location_name  \
# 0  competitor auctions  166 AUTO AUCTION
# 1  competitor auctions  411 AUTO AUCTION
# 2  competitor auctions  AAA ALLIANCE AUTO AUCTION- DALLAS
#
#                                            addr        lat       long
# 0  2944 WEST SUNSHINE ST, SPRINGFIELD, MO 65807  37.181888 -93.337763
# 1  3824 HIGHWAY 411, KINGSTON, GA 30145          34.201204 -84.998695
# 2  9426 LAKEFIELD BLVD, DALLAS, TX 75220         32.858631 -96.862701

# %%
auctions_georgia = auctions.loc[auctions.addr.map(lambda x: ' GA ' in x)]
auctions_georgia = auctions_georgia.reset_index().drop(columns='index')
auctions_georgia
# Out:
#            location_cat                          location_name  \
# 0   competitor auctions  411 AUTO AUCTION
# 1   competitor auctions  ADESA ATLANTA
# 2   competitor auctions  AMERICA'S AUTO AUCTION ATLANTA
# 3   competitor auctions  CARMAX NORCROSS
# 4   competitor auctions  CARMAX STOCKBRIDGE
# 5   competitor auctions  CARMAX KENNESAW
# 6   competitor auctions  COPART ATLANTA EAST/WEST/SOUTH/NORTH
# 7   competitor auctions  COPART CARTERSVILLE
# 8   competitor auctions  COPART SAVANNAH
# 9   competitor auctions  COPART TIFTON
# 10  competitor auctions  IAA ATLANTA/EAST/NORTH/SOUTH
# 11  competitor auctions  IAA MACON
# 12  competitor auctions  IAA SAVANNAH
# 13  competitor auctions  IAA TIFTON
# 14  manheim              MANHEIM ATLANTA
# 15  manheim              MANHEIM GEORGIA
# 16  manheim              MANHEIM METRO ATLANTA
# 17  competitor auctions  SOUTHEASTERN AUTO AUCTION OF SAVANNAH
# 18  competitor auctions  V.I.P AUTO AUCTION ATLANTA
# 19  competitor auctions  VEMO WARNER ROBBINS
# 20  competitor auctions  WESTWOOD AUTO AUCTION
#
#                                                  addr        lat       long
# 0   3824 HIGHWAY 411, KINGSTON, GA 30145               34.201204 -84.998695
# 1   5055 OAKLEY INDUSTRIAL BLVD, FAIRBURN, GA 30213    33.547412 -84.549661
# 2   444 JOE FRANK HARRIS PKWY, CARTERSVILLE, GA 30120  34.145539 -84.745675
# 3   1975 BEAVER RUIN RD, NORCROSS, GA 30071            33.932711 -84.171008
# 4   3100 MT. ZION PKWY, STOCKBRIDGE, GA 30281          33.549901 -84.289497
# 5   1215 ERNEST BARRETT PKWY, KENNESAW, GA 30144       33.998176 -84.584873
# 6   6089 HIGHWAY 20, LOGANVILLE, GA 30052              33.804355 -83.955132
# 7   1880 HWY 113, CARTERSVILLE, GA 30120               34.117550 -84.892990
# 8   5510 SILK HOPE ROAD, SAVANNAH, GA 31405            32.040761 -81.212716
# 9   399 OAKRIDGE CHURCH RD, TIFTON, GA 31794           31.406281 -83.487636
# 10  125 OLD HIGHWAY 138, LOGANVILLE, GA 30052          33.724936 -83.912646
# 11  2200 TRADE DR, MACON, GA 31217                     32.848037 -83.584819
# 12  348 COMMERCE DR, RINCON, GA 31326                  32.246017 -81.201373
# 13  368 OAK RIDGE CHURCH RD, TIFTON, GA 31794          31.400558 -83.489980
# 14  4900 BUFFINGTON RD, RED OAK, GA 30349              33.619200 -84.494880
# 15  7205 CAMPBELLTON RD, ATLANTA, GA 30331             33.694709 -84.622871
# 16  2244 METROPOLITAN PARKWAY, ATLANTA, GA 30315       33.692137 -84.405919
# 17  1712 DEAN FOREST RD, SAVANNAH, GA 31408            32.086710 -81.196633
# 18  4180 BUFORD DR, BUFORD, GA 30518                   34.091570 -84.006785
# 19  441 DUNBAR RD, WARNER ROBBINS, GA 31093            32.652433 -83.648684
# 20  1818 BANKHEAD HIGHWAY, CARROLLTON, GA 30116        33.608388 -85.017966

# %%
auctions_georgia_flat = [str(name)+'|'+str(lat)+','+str(long)
                         for name,lat,long in zip(auctions_georgia.location_name,auctions_georgia.lat,auctions_georgia.long)
                        ]

# %%
auctions_georgia_flat
# Out:
# ['411 AUTO AUCTION|34.2012036,-84.998695',
#  'ADESA ATLANTA|33.5474124,-84.5496607',
#  "AMERICA'S AUTO AUCTION ATLANTA|34.1455393,-84.7456754",
#  'CARMAX NORCROSS|33.9327112,-84.1710076',
#  'CARMAX STOCKBRIDGE|33.5499008,-84.2894974',
#  'CARMAX KENNESAW|33.9981764,-84.5848731',
#  'COPART ATLANTA EAST/WEST/SOUTH/NORTH|33.8043554,-83.9551319',
#  'COPART CARTERSVILLE|34.1175502,-84.8929903',
#  'COPART SAVANNAH|32.0407614,-81.2127155',
#  'COPART TIFTON|31.406281,-83.487636',
#  'IAA ATLANTA/EAST/NORTH/SOUTH|33.7249363,-83.912646',
#  'IAA MACON|32.848037,-83.584819',
#  'IAA SAVANNAH|32.2460172,-81.2013731',
#  'IAA TIFTON|31.4005578,-83.4899801',
#  'MANHEIM ATLANTA|33.6192003,-84.49488',
#  'MANHEIM GEORGIA|33.6947088,-84.6228706',
#  'MANHEIM METRO ATLANTA|33.6921367,-84.4059195',
#  'SOUTHEASTERN AUTO AUCTION OF SAVANNAH|32.0867103,-81.1966333',
#  'V.I.P AUTO AUCTION ATLANTA|34.09157,-84.0067847',
#  'VEMO WARNER ROBBINS|32.652433,-83.648684',
#  'WESTWOOD AUTO AUCTION|33.6083878,-85.017966']

# %%
len(auctions_georgia_flat)
# Out:
# 21

# %% [markdown]
# # step 7: identify the new locations

# %%
auctions_new = sorted(list(auctions_new))
auctions_new[:9]
# Out:
# ['Albany Auto Auction|31.5092048,-84.1166549|1421 Liberty Expy, Albany, GA 31705',
#  'Athens Auto Auction|33.9443602,-83.507815|5050 Atlanta Hwy, Bogart, GA 30622',
#  'Augusta Auto Auction|33.4827023,-81.9460647|395 Hamburg Rd, North Augusta, SC 29841',
#  'Auto Auction Services Corporation|33.9405501,-84.361437|50 Glenlake Pkwy NE, Atlanta, GA 30328',
#  'Auto Auctions|33.954841,-84.198661|2775 Northwoods Pkwy, Norcross, GA 30071',
#  'AutoNation Auto Auction Atlanta|33.6303677,-84.3080105|2491 Old Anvil Block Rd, Ellenwood, GA 30294',
#  'Georgia - Carolina Auto Auction|34.2589807,-83.4892078|884 E Ridgeway Rd, Commerce, GA 30529',
#  'Hwy 515 Auto Auction|34.741224,-84.42113300000001|107 Whitepath Rd, Ellijay, GA 30540',
#  'Oakwoods Arrow Auto Auction|34.2334842,-83.8984545|4712 Flat Creek Rd, Oakwood, GA 30566']

# %%
auctions_new.pop(3)
auctions_new.pop(3)
# Out:
# 'Auto Auctions|33.954841,-84.198661|2775 Northwoods Pkwy, Norcross, GA 30071'

# %%
auctions_new
# Out:
# ['Albany Auto Auction|31.5092048,-84.1166549|1421 Liberty Expy, Albany, GA 31705',
#  'Athens Auto Auction|33.9443602,-83.507815|5050 Atlanta Hwy, Bogart, GA 30622',
#  'Augusta Auto Auction|33.4827023,-81.9460647|395 Hamburg Rd, North Augusta, SC 29841',
#  'AutoNation Auto Auction Atlanta|33.6303677,-84.3080105|2491 Old Anvil Block Rd, Ellenwood, GA 30294',
#  'Georgia - Carolina Auto Auction|34.2589807,-83.4892078|884 E Ridgeway Rd, Commerce, GA 30529',
#  'Hwy 515 Auto Auction|34.741224,-84.42113300000001|107 Whitepath Rd, Ellijay, GA 30540',
#  'Oakwoods Arrow Auto Auction|34.2334842,-83.8984545|4712 Flat Creek Rd, Oakwood, GA 30566',
#  'Southeastern Auto Auction|32.0867058,-81.1966333|1712 Dean Forest Rd, Savannah, GA 31408',
#  'VEMO Auto Auctions|32.6510009,-83.64865979999999|441 Dunbar Rd, Warner Robins, GA 31093']

# %%
m = folium.Map([33.909508, -84.355094], zoom_start=6)

# mark all cluster locations
for location in auctionlike_georgia:
    folium.Marker(
        [location[0], location[1]],
        icon=folium.Icon(color='red')
    ).add_to(m)

# mark all the auctions found via google
for location in auctions_new[:9]:
      folium.Marker(
        [float(location.split('|')[1].split(',')[0]), float(location.split('|')[1].split(',')[1])],
        popup=folium.Popup(location.split('|')[0],parse_html=True),
        icon=folium.Icon(color='green')
    ).add_to(m)  

# mark all the known auctions in Georgia
for location in auctions_georgia_flat:
      folium.Marker(
        [float(location.split('|')[1].split(',')[0]), float(location.split('|')[1].split(',')[1])],
        popup=folium.Popup(location.split('|')[0],parse_html=True),
        icon=folium.Icon(color='blue')
    ).add_to(m)  

m.save('../metadata/test.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # step 8: elbow plot for Georgia blobs

# %%
auctions_new
# Out:
# ['Albany Auto Auction|31.5092048,-84.1166549|1421 Liberty Expy, Albany, GA 31705',
#  'Athens Auto Auction|33.9443602,-83.507815|5050 Atlanta Hwy, Bogart, GA 30622',
#  'Augusta Auto Auction|33.4827023,-81.9460647|395 Hamburg Rd, North Augusta, SC 29841',
#  'AutoNation Auto Auction Atlanta|33.6303677,-84.3080105|2491 Old Anvil Block Rd, Ellenwood, GA 30294',
#  'Georgia - Carolina Auto Auction|34.2589807,-83.4892078|884 E Ridgeway Rd, Commerce, GA 30529',
#  'Hwy 515 Auto Auction|34.741224,-84.42113300000001|107 Whitepath Rd, Ellijay, GA 30540',
#  'Oakwoods Arrow Auto Auction|34.2334842,-83.8984545|4712 Flat Creek Rd, Oakwood, GA 30566',
#  'Southeastern Auto Auction|32.0867058,-81.1966333|1712 Dean Forest Rd, Savannah, GA 31408',
#  'VEMO Auto Auctions|32.6510009,-83.64865979999999|441 Dunbar Rd, Warner Robins, GA 31093']

# %%
auctionlike.head(3)
# Out:
#      lat3   long3  cluster_id
# 0  38.347 -77.488  6
# 1  33.620 -84.499  1
# 2  40.886 -81.566  6

# %%
auctionlike_df = pd.DataFrame(auctionlike_georgia, columns=['lat','long'])
auctionlike_df.shape
# Out:
# (212, 2)

# %% [markdown]
# ## 8.2: append auction list

# %%
auctions_new = auctions_new[:7]

# %%
auctions_new
# Out:
# ['Albany Auto Auction|31.5092048,-84.1166549|1421 Liberty Expy, Albany, GA 31705',
#  'Athens Auto Auction|33.9443602,-83.507815|5050 Atlanta Hwy, Bogart, GA 30622',
#  'Augusta Auto Auction|33.4827023,-81.9460647|395 Hamburg Rd, North Augusta, SC 29841',
#  'AutoNation Auto Auction Atlanta|33.6303677,-84.3080105|2491 Old Anvil Block Rd, Ellenwood, GA 30294',
#  'Georgia - Carolina Auto Auction|34.2589807,-83.4892078|884 E Ridgeway Rd, Commerce, GA 30529',
#  'Hwy 515 Auto Auction|34.741224,-84.42113300000001|107 Whitepath Rd, Ellijay, GA 30540',
#  'Oakwoods Arrow Auto Auction|34.2334842,-83.8984545|4712 Flat Creek Rd, Oakwood, GA 30566']

# %%
auctions_georgia_flat
# Out:
# ['411 AUTO AUCTION|34.2012036,-84.998695',
#  'ADESA ATLANTA|33.5474124,-84.5496607',
#  "AMERICA'S AUTO AUCTION ATLANTA|34.1455393,-84.7456754",
#  'CARMAX NORCROSS|33.9327112,-84.1710076',
#  'CARMAX STOCKBRIDGE|33.5499008,-84.2894974',
#  'CARMAX KENNESAW|33.9981764,-84.5848731',
#  'COPART ATLANTA EAST/WEST/SOUTH/NORTH|33.8043554,-83.9551319',
#  'COPART CARTERSVILLE|34.1175502,-84.8929903',
#  'COPART SAVANNAH|32.0407614,-81.2127155',
#  'COPART TIFTON|31.406281,-83.487636',
#  'IAA ATLANTA/EAST/NORTH/SOUTH|33.7249363,-83.912646',
#  'IAA MACON|32.848037,-83.584819',
#  'IAA SAVANNAH|32.2460172,-81.2013731',
#  'IAA TIFTON|31.4005578,-83.4899801',
#  'MANHEIM ATLANTA|33.6192003,-84.49488',
#  'MANHEIM GEORGIA|33.6947088,-84.6228706',
#  'MANHEIM METRO ATLANTA|33.6921367,-84.4059195',
#  'SOUTHEASTERN AUTO AUCTION OF SAVANNAH|32.0867103,-81.1966333',
#  'V.I.P AUTO AUCTION ATLANTA|34.09157,-84.0067847',
#  'VEMO WARNER ROBBINS|32.652433,-83.648684',
#  'WESTWOOD AUTO AUCTION|33.6083878,-85.017966']

# %%
len(auctions_georgia_flat)
# Out:
# 21

# %%
auctions_known = pd.DataFrame([
    (
        location.split('|')[1].split(',')[0],
        location.split('|')[1].split(',')[1],
        location.split('|')[0]
    )
    for location in auctions_georgia_flat
], columns=['lat','long','name'])

auctions_new2 = pd.DataFrame([
    (
        location.split('|')[1].split(',')[0],
        location.split('|')[1].split(',')[1],
        location.split('|')[0]
    )
    for location in auctions_new
], columns=['lat','long','name'])

# %%
auctionlike_df['name']='Unknown'

# %%
auctionlike_df2 = pd.concat([
    auctionlike_df,
    auctions_known,
    auctions_new2
], ignore_index=True)

auctionlike_df2.lat = auctionlike_df2.lat.map(lambda x: float(x))
auctionlike_df2.long = auctionlike_df2.long.map(lambda x: float(x))

# %%
auctionlike_df2.head(3)
# Out:
#       lat    long     name
# 0  33.620 -84.499  Unknown
# 1  34.147 -84.746  Unknown
# 2  32.652 -83.648  Unknown

# %%
auctionlist = auctionlike_df2.loc[auctionlike_df2.name!='Unknown'].copy()

# %%
auctionlist
# Out:
#            lat       long                                   name
# 212  34.201204 -84.998695  411 AUTO AUCTION
# 213  33.547412 -84.549661  ADESA ATLANTA
# 214  34.145539 -84.745675  AMERICA'S AUTO AUCTION ATLANTA
# 215  33.932711 -84.171008  CARMAX NORCROSS
# 216  33.549901 -84.289497  CARMAX STOCKBRIDGE
# 217  33.998176 -84.584873  CARMAX KENNESAW
# 218  33.804355 -83.955132  COPART ATLANTA EAST/WEST/SOUTH/NORTH
# 219  34.117550 -84.892990  COPART CARTERSVILLE
# 220  32.040761 -81.212716  COPART SAVANNAH
# 221  31.406281 -83.487636  COPART TIFTON
# 222  33.724936 -83.912646  IAA ATLANTA/EAST/NORTH/SOUTH
# 223  32.848037 -83.584819  IAA MACON
# 224  32.246017 -81.201373  IAA SAVANNAH
# 225  31.400558 -83.489980  IAA TIFTON
# 226  33.619200 -84.494880  MANHEIM ATLANTA
# 227  33.694709 -84.622871  MANHEIM GEORGIA
# 228  33.692137 -84.405919  MANHEIM METRO ATLANTA
# 229  32.086710 -81.196633  SOUTHEASTERN AUTO AUCTION OF SAVANNAH
# 230  34.091570 -84.006785  V.I.P AUTO AUCTION ATLANTA
# 231  32.652433 -83.648684  VEMO WARNER ROBBINS
# 232  33.608388 -85.017966  WESTWOOD AUTO AUCTION
# 233  31.509205 -84.116655  Albany Auto Auction
# 234  33.944360 -83.507815  Athens Auto Auction
# 235  33.482702 -81.946065  Augusta Auto Auction
# 236  33.630368 -84.308010  AutoNation Auto Auction Atlanta
# 237  34.258981 -83.489208  Georgia - Carolina Auto Auction
# 238  34.741224 -84.421133  Hwy 515 Auto Auction
# 239  34.233484 -83.898454  Oakwoods Arrow Auto Auction

# %%
auctionlist['lat_low'] = auctionlist.lat.map(lambda x: round(x,2)-0.02)
auctionlist['lat_high'] = auctionlist.lat.map(lambda x: round(x,2)+0.02)
auctionlist['long_low'] = auctionlist.long.map(lambda x: round(x,2)-0.02)
auctionlist['long_high'] = auctionlist.long.map(lambda x: round(x,2)+0.02)

# %%
auctionlist.head(3)
# Out:
#            lat       long                            name  lat_low  lat_high  \
# 212  34.201204 -84.998695  411 AUTO AUCTION                34.18    34.22
# 213  33.547412 -84.549661  ADESA ATLANTA                   33.53    33.57
# 214  34.145539 -84.745675  AMERICA'S AUTO AUCTION ATLANTA  34.13    34.17
#
#      long_low  long_high
# 212 -85.02    -84.98
# 213 -84.57    -84.53
# 214 -84.77    -84.73

# %%
auctionlist.name.nunique()
# Out:
# 28

# %%
auctionlist['comm'] = 1
unknowns = auctionlike_df2.copy()
unknowns['comm'] = 1


combo = pd.merge(
    auctionlist.rename(columns={'lat':'lat_poi','long':'long_poi'}),
    unknowns.rename(columns={'name':'label'}),
    on='comm'
)

combo.head(3)
# Out:
#      lat_poi   long_poi              name  lat_low  lat_high  long_low  \
# 0  34.201204 -84.998695  411 AUTO AUCTION  34.18    34.22    -85.02
# 1  34.201204 -84.998695  411 AUTO AUCTION  34.18    34.22    -85.02
# 2  34.201204 -84.998695  411 AUTO AUCTION  34.18    34.22    -85.02
#
#    long_high  comm     lat    long    label
# 0 -84.98      1     33.620 -84.499  Unknown
# 1 -84.98      1     34.147 -84.746  Unknown
# 2 -84.98      1     32.652 -83.648  Unknown

# %%
combo2 = combo.loc[
    (combo.lat>=combo.lat_low)\
    &(combo.lat<=combo.lat_high)\
    &(combo.long>=combo.long_low)\
    &(combo.long<=combo.long_high)
]

# %%
combo2.shape
# Out:
# (220, 11)

# %%
combo2_agg_p1 = combo2.groupby(['name','lat_poi','long_poi'])[['lat','long']].min().reset_index().rename(
    columns={
        'lat':'southwest_lat',
        'long':'southwest_long'
    }
)
combo2_agg_p2 = combo2.groupby(['name','lat_poi','long_poi'])[['lat','long']].max().reset_index().rename(
    columns={
        'lat':'northeast_lat',
        'long':'northeast_long'
    }
)

combo2_agg = pd.merge(
    combo2_agg_p1,
    combo2_agg_p2,
    on=['name','lat_poi','long_poi']
)

# %%
combo2_agg
# Out:
#                                      name    lat_poi   long_poi  \
# 0   411 AUTO AUCTION                       34.201204 -84.998695
# 1   ADESA ATLANTA                          33.547412 -84.549661
# 2   AMERICA'S AUTO AUCTION ATLANTA         34.145539 -84.745675
# 3   Albany Auto Auction                    31.509205 -84.116655
# 4   Athens Auto Auction                    33.944360 -83.507815
# 5   Augusta Auto Auction                   33.482702 -81.946065
# 6   AutoNation Auto Auction Atlanta        33.630368 -84.308010
# 7   CARMAX KENNESAW                        33.998176 -84.584873
# 8   CARMAX NORCROSS                        33.932711 -84.171008
# 9   CARMAX STOCKBRIDGE                     33.549901 -84.289497
# 10  COPART ATLANTA EAST/WEST/SOUTH/NORTH   33.804355 -83.955132
# 11  COPART CARTERSVILLE                    34.117550 -84.892990
# 12  COPART SAVANNAH                        32.040761 -81.212716
# 13  COPART TIFTON                          31.406281 -83.487636
# 14  Georgia - Carolina Auto Auction        34.258981 -83.489208
# 15  Hwy 515 Auto Auction                   34.741224 -84.421133
# 16  IAA ATLANTA/EAST/NORTH/SOUTH           33.724936 -83.912646
# 17  IAA MACON                              32.848037 -83.584819
# 18  IAA SAVANNAH                           32.246017 -81.201373
# 19  IAA TIFTON                             31.400558 -83.489980
# 20  MANHEIM ATLANTA                        33.619200 -84.494880
# 21  MANHEIM GEORGIA                        33.694709 -84.622871
# 22  MANHEIM METRO ATLANTA                  33.692137 -84.405919
# 23  Oakwoods Arrow Auto Auction            34.233484 -83.898454
# 24  SOUTHEASTERN AUTO AUCTION OF SAVANNAH  32.086710 -81.196633
# 25  V.I.P AUTO AUCTION ATLANTA             34.091570 -84.006785
# 26  VEMO WARNER ROBBINS                    32.652433 -83.648684
# 27  WESTWOOD AUTO AUCTION                  33.608388 -85.017966
#
#     southwest_lat  southwest_long  northeast_lat  northeast_long
# 0   34.201204     -84.998695       34.201204     -84.998695
# 1   33.537000     -84.567000       33.548000     -84.548000
# 2   34.140000     -84.758000       34.168000     -84.744000
# 3   31.509000     -84.116655       31.509205     -84.116000
# 4   33.944000     -83.509000       33.944360     -83.506000
# 5   33.482000     -81.947000       33.484000     -81.946000
# 6   33.629000     -84.308010       33.631000     -84.305000
# 7   33.998000     -84.585000       33.998176     -84.583000
# 8   33.932000     -84.171008       33.933000     -84.167000
# 9   33.549000     -84.291000       33.550000     -84.289497
# 10  33.804355     -83.955132       33.804355     -83.955132
# 11  34.117550     -84.892990       34.117550     -84.892990
# 12  32.040761     -81.212716       32.040761     -81.212716
# 13  31.400558     -83.489980       31.406281     -83.487636
# 14  34.258981     -83.490000       34.259000     -83.489000
# 15  34.741000     -84.422000       34.741224     -84.421133
# 16  33.724936     -83.912646       33.724936     -83.912646
# 17  32.848037     -83.584819       32.848037     -83.584819
# 18  32.246017     -81.201373       32.246017     -81.201373
# 19  31.400558     -83.489980       31.406281     -83.487636
# 20  33.612000     -84.502000       33.625000     -84.483000
# 21  33.693000     -84.626000       33.698000     -84.621000
# 22  33.692000     -84.407000       33.693000     -84.404000
# 23  34.233000     -83.899000       34.234000     -83.897000
# 24  32.085000     -81.197000       32.087000     -81.194000
# 25  34.091570     -84.006785       34.091570     -84.006785
# 26  32.651000     -83.649000       32.652433     -83.648000
# 27  33.608000     -85.018000       33.608388     -85.017966

# %%
combo2_agg_copy = combo2_agg.copy()

combo2_agg.loc[
    (combo2_agg_copy.southwest_lat>combo2_agg_copy.northeast_lat-0.001),
    'southwest_lat'
] = combo2_agg.loc[
    (combo2_agg_copy.southwest_lat>combo2_agg_copy.northeast_lat-0.001),
    'lat_poi'
] - 0.001

combo2_agg.loc[
    (combo2_agg_copy.southwest_lat>combo2_agg_copy.northeast_lat-0.001),
    'northeast_lat'
] = combo2_agg.loc[
    (combo2_agg_copy.southwest_lat>combo2_agg_copy.northeast_lat-0.001),
    'lat_poi'
] + 0.001

combo2_agg.loc[
    (combo2_agg_copy.southwest_long>combo2_agg_copy.northeast_long-0.001),
    'southwest_long'
] = combo2_agg.loc[
    (combo2_agg_copy.southwest_long>combo2_agg_copy.northeast_long-0.001),
    'long_poi'
] - 0.001

combo2_agg.loc[
    (combo2_agg_copy.southwest_long>combo2_agg_copy.northeast_long-0.001),
    'northeast_long'
] = combo2_agg.loc[
    (combo2_agg_copy.southwest_long>combo2_agg_copy.northeast_long-0.001),
    'long_poi'
] + 0.001

# %%
combo2_agg
# Out:
#                                      name    lat_poi   long_poi  \
# 0   411 AUTO AUCTION                       34.201204 -84.998695
# 1   ADESA ATLANTA                          33.547412 -84.549661
# 2   AMERICA'S AUTO AUCTION ATLANTA         34.145539 -84.745675
# 3   Albany Auto Auction                    31.509205 -84.116655
# 4   Athens Auto Auction                    33.944360 -83.507815
# 5   Augusta Auto Auction                   33.482702 -81.946065
# 6   AutoNation Auto Auction Atlanta        33.630368 -84.308010
# 7   CARMAX KENNESAW                        33.998176 -84.584873
# 8   CARMAX NORCROSS                        33.932711 -84.171008
# 9   CARMAX STOCKBRIDGE                     33.549901 -84.289497
# 10  COPART ATLANTA EAST/WEST/SOUTH/NORTH   33.804355 -83.955132
# 11  COPART CARTERSVILLE                    34.117550 -84.892990
# 12  COPART SAVANNAH                        32.040761 -81.212716
# 13  COPART TIFTON                          31.406281 -83.487636
# 14  Georgia - Carolina Auto Auction        34.258981 -83.489208
# 15  Hwy 515 Auto Auction                   34.741224 -84.421133
# 16  IAA ATLANTA/EAST/NORTH/SOUTH           33.724936 -83.912646
# 17  IAA MACON                              32.848037 -83.584819
# 18  IAA SAVANNAH                           32.246017 -81.201373
# 19  IAA TIFTON                             31.400558 -83.489980
# 20  MANHEIM ATLANTA                        33.619200 -84.494880
# 21  MANHEIM GEORGIA                        33.694709 -84.622871
# 22  MANHEIM METRO ATLANTA                  33.692137 -84.405919
# 23  Oakwoods Arrow Auto Auction            34.233484 -83.898454
# 24  SOUTHEASTERN AUTO AUCTION OF SAVANNAH  32.086710 -81.196633
# 25  V.I.P AUTO AUCTION ATLANTA             34.091570 -84.006785
# 26  VEMO WARNER ROBBINS                    32.652433 -83.648684
# 27  WESTWOOD AUTO AUCTION                  33.608388 -85.017966
#
#     southwest_lat  southwest_long  northeast_lat  northeast_long
# 0   34.200204     -84.999695       34.202204     -84.997695
# 1   33.537000     -84.567000       33.548000     -84.548000
# 2   34.140000     -84.758000       34.168000     -84.744000
# 3   31.508205     -84.117655       31.510205     -84.115655
# 4   33.943360     -83.509000       33.945360     -83.506000
# 5   33.482000     -81.947000       33.484000     -81.946000
# 6   33.629000     -84.308010       33.631000     -84.305000
# 7   33.997176     -84.585000       33.999176     -84.583000
# 8   33.932000     -84.171008       33.933000     -84.167000
# 9   33.549000     -84.291000       33.550000     -84.289497
# 10  33.803355     -83.956132       33.805355     -83.954132
# 11  34.116550     -84.893990       34.118550     -84.891990
# 12  32.039761     -81.213716       32.041761     -81.211715
# 13  31.400558     -83.489980       31.406281     -83.487636
# 14  34.257981     -83.490000       34.259981     -83.489000
# 15  34.740224     -84.422133       34.742224     -84.420133
# 16  33.723936     -83.913646       33.725936     -83.911646
# 17  32.847037     -83.585819       32.849037     -83.583819
# 18  32.245017     -81.202373       32.247017     -81.200373
# 19  31.400558     -83.489980       31.406281     -83.487636
# 20  33.612000     -84.502000       33.625000     -84.483000
# 21  33.693000     -84.626000       33.698000     -84.621000
# 22  33.692000     -84.407000       33.693000     -84.404000
# 23  34.233000     -83.899000       34.234000     -83.897000
# 24  32.085000     -81.197000       32.087000     -81.194000
# 25  34.090570     -84.007785       34.092570     -84.005785
# 26  32.651000     -83.649000       32.652433     -83.648000
# 27  33.607388     -85.018966       33.609388     -85.016966

# %%
combo2_agg['fence'] = [
    [
        (southwest_lat,southwest_long),
        (southwest_lat,northeast_long),
        (northeast_lat,northeast_long),
        (northeast_lat,southwest_long),
        (southwest_lat,southwest_long)
    ]
    for southwest_lat,southwest_long,northeast_lat,northeast_long in zip(
        combo2_agg.southwest_lat,
        combo2_agg.southwest_long,
        combo2_agg.northeast_lat,
        combo2_agg.northeast_long
    )
]

# %%
combo2_agg
# Out:
#                                      name    lat_poi   long_poi  \
# 0   411 AUTO AUCTION                       34.201204 -84.998695
# 1   ADESA ATLANTA                          33.547412 -84.549661
# 2   AMERICA'S AUTO AUCTION ATLANTA         34.145539 -84.745675
# 3   Albany Auto Auction                    31.509205 -84.116655
# 4   Athens Auto Auction                    33.944360 -83.507815
# 5   Augusta Auto Auction                   33.482702 -81.946065
# 6   AutoNation Auto Auction Atlanta        33.630368 -84.308010
# 7   CARMAX KENNESAW                        33.998176 -84.584873
# 8   CARMAX NORCROSS                        33.932711 -84.171008
# 9   CARMAX STOCKBRIDGE                     33.549901 -84.289497
# 10  COPART ATLANTA EAST/WEST/SOUTH/NORTH   33.804355 -83.955132
# 11  COPART CARTERSVILLE                    34.117550 -84.892990
# 12  COPART SAVANNAH                        32.040761 -81.212716
# 13  COPART TIFTON                          31.406281 -83.487636
# 14  Georgia - Carolina Auto Auction        34.258981 -83.489208
# 15  Hwy 515 Auto Auction                   34.741224 -84.421133
# 16  IAA ATLANTA/EAST/NORTH/SOUTH           33.724936 -83.912646
# 17  IAA MACON                              32.848037 -83.584819
# 18  IAA SAVANNAH                           32.246017 -81.201373
# 19  IAA TIFTON                             31.400558 -83.489980
# 20  MANHEIM ATLANTA                        33.619200 -84.494880
# 21  MANHEIM GEORGIA                        33.694709 -84.622871
# 22  MANHEIM METRO ATLANTA                  33.692137 -84.405919
# 23  Oakwoods Arrow Auto Auction            34.233484 -83.898454
# 24  SOUTHEASTERN AUTO AUCTION OF SAVANNAH  32.086710 -81.196633
# 25  V.I.P AUTO AUCTION ATLANTA             34.091570 -84.006785
# 26  VEMO WARNER ROBBINS                    32.652433 -83.648684
# 27  WESTWOOD AUTO AUCTION                  33.608388 -85.017966
#
#     southwest_lat  southwest_long  northeast_lat  northeast_long  \
# 0   34.200204     -84.999695       34.202204     -84.997695
# 1   33.537000     -84.567000       33.548000     -84.548000
# 2   34.140000     -84.758000       34.168000     -84.744000
# 3   31.508205     -84.117655       31.510205     -84.115655
# 4   33.943360     -83.509000       33.945360     -83.506000
# 5   33.482000     -81.947000       33.484000     -81.946000
# 6   33.629000     -84.308010       33.631000     -84.305000
# 7   33.997176     -84.585000       33.999176     -84.583000
# 8   33.932000     -84.171008       33.933000     -84.167000
# 9   33.549000     -84.291000       33.550000     -84.289497
# 10  33.803355     -83.956132       33.805355     -83.954132
# 11  34.116550     -84.893990       34.118550     -84.891990
# 12  32.039761     -81.213716       32.041761     -81.211715
# 13  31.400558     -83.489980       31.406281     -83.487636
# 14  34.257981     -83.490000       34.259981     -83.489000
# 15  34.740224     -84.422133       34.742224     -84.420133
# 16  33.723936     -83.913646       33.725936     -83.911646
# 17  32.847037     -83.585819       32.849037     -83.583819
# 18  32.245017     -81.202373       32.247017     -81.200373
# 19  31.400558     -83.489980       31.406281     -83.487636
# 20  33.612000     -84.502000       33.625000     -84.483000
# 21  33.693000     -84.626000       33.698000     -84.621000
# 22  33.692000     -84.407000       33.693000     -84.404000
# 23  34.233000     -83.899000       34.234000     -83.897000
# 24  32.085000     -81.197000       32.087000     -81.194000
# 25  34.090570     -84.007785       34.092570     -84.005785
# 26  32.651000     -83.649000       32.652433     -83.648000
# 27  33.607388     -85.018966       33.609388     -85.016966
#
#                                                                                                                                                                                          fence
# 0   [(34.2002036, -84.999695), (34.2002036, -84.997695), (34.2022036, -84.997695), (34.2022036, -84.999695), (34.2002036, -84.999695)]
# 1   [(33.537, -84.56700000000001), (33.537, -84.54799999999999), (33.548, -84.54799999999999), (33.548, -84.56700000000001), (33.537, -84.56700000000001)]
# 2   [(34.14, -84.758), (34.14, -84.744), (34.168, -84.744), (34.168, -84.758), (34.14, -84.758)]
# 3   [(31.508204799999998, -84.1176549), (31.508204799999998, -84.1156549), (31.5102048, -84.1156549), (31.5102048, -84.1176549), (31.508204799999998, -84.1176549)]
# 4   [(33.9433602, -83.509), (33.9433602, -83.506), (33.945360199999996, -83.506), (33.945360199999996, -83.509), (33.9433602, -83.509)]
# 5   [(33.482, -81.947), (33.482, -81.946), (33.484, -81.946), (33.484, -81.947), (33.482, -81.947)]
# 6   [(33.629, -84.3080105), (33.629, -84.305), (33.631, -84.305), (33.631, -84.3080105), (33.629, -84.3080105)]
# 7   [(33.9971764, -84.585), (33.9971764, -84.583), (33.999176399999996, -84.583), (33.999176399999996, -84.585), (33.9971764, -84.585)]
# 8   [(33.931999999999995, -84.1710076), (33.931999999999995, -84.167), (33.933, -84.167), (33.933, -84.1710076), (33.931999999999995, -84.1710076)]
# 9   [(33.549, -84.291), (33.549, -84.2894974), (33.55, -84.2894974), (33.55, -84.291), (33.549, -84.291)]
# 10  [(33.8033554, -83.9561319), (33.8033554, -83.9541319), (33.805355399999996, -83.9541319), (33.805355399999996, -83.9561319), (33.8033554, -83.9561319)]
# 11  [(34.1165502, -84.8939903), (34.1165502, -84.89199029999999), (34.118550199999994, -84.89199029999999), (34.118550199999994, -84.8939903), (34.1165502, -84.8939903)]
# 12  [(32.0397614, -81.2137155), (32.0397614, -81.2117155), (32.0417614, -81.2117155), (32.0417614, -81.2137155), (32.0397614, -81.2137155)]
# 13  [(31.4005578, -83.4899801), (31.4005578, -83.487636), (31.406281, -83.487636), (31.406281, -83.4899801), (31.4005578, -83.4899801)]
# 14  [(34.257980700000005, -83.49), (34.257980700000005, -83.48899999999999), (34.2599807, -83.48899999999999), (34.2599807, -83.49), (34.257980700000005, -83.49)]
# 15  [(34.740224000000005, -84.42213300000002), (34.740224000000005, -84.420133), (34.742224, -84.420133), (34.742224, -84.42213300000002), (34.740224000000005, -84.42213300000002)]
# 16  [(33.723936300000005, -83.913646), (33.723936300000005, -83.91164599999999), (33.7259363, -83.91164599999999), (33.7259363, -83.913646), (33.723936300000005, -83.913646)]
# 17  [(32.847037, -83.585819), (32.847037, -83.58381899999999), (32.849036999999996, -83.58381899999999), (32.849036999999996, -83.585819), (32.847037, -83.585819)]
# 18  [(32.2450172, -81.2023731), (32.2450172, -81.2003731), (32.247017199999995, -81.2003731), (32.247017199999995, -81.2023731), (32.2450172, -81.2023731)]
# 19  [(31.4005578, -83.4899801), (31.4005578, -83.487636), (31.406281, -83.487636), (31.406281, -83.4899801), (31.4005578, -83.4899801)]
# 20  [(33.611999999999995, -84.50200000000001), (33.611999999999995, -84.48299999999999), (33.625, -84.48299999999999), (33.625, -84.50200000000001), (33.611999999999995, -84.50200000000001)]
# 21  [(33.693000000000005, -84.626), (33.693000000000005, -84.62100000000001), (33.698, -84.62100000000001), (33.698, -84.626), (33.693000000000005, -84.626)]
# 22  [(33.692, -84.40700000000001), (33.692, -84.404), (33.693000000000005, -84.404), (33.693000000000005, -84.40700000000001), (33.692, -84.40700000000001)]
# 23  [(34.233000000000004, -83.899), (34.233000000000004, -83.897), (34.234, -83.897), (34.234, -83.899), (34.233000000000004, -83.899)]
# 24  [(32.085, -81.197), (32.085, -81.194), (32.086999999999996, -81.194), (32.086999999999996, -81.197), (32.085, -81.197)]
# 25  [(34.09057, -84.0077847), (34.09057, -84.00578469999999), (34.092569999999995, -84.00578469999999), (34.092569999999995, -84.0077847), (34.09057, -84.0077847)]
# 26  [(32.650999999999996, -83.649), (32.650999999999996, -83.648), (32.652433, -83.648), (32.652433, -83.649), (32.650999999999996, -83.649)]
# 27  [(33.607387800000005, -85.018966), (33.607387800000005, -85.016966), (33.6093878, -85.016966), (33.6093878, -85.018966), (33.607387800000005, -85.018966)]

# %%
m = folium.Map([33.909508, -84.355094], zoom_start=6)

# mark all cluster locations
for location in auctionlike_georgia:
    folium.Marker(
        [location[0], location[1]],
        icon=folium.Icon(color='red')
    ).add_to(m)

# mark all the auctions found via google
for location in auctions_new[:7]:
      folium.Marker(
        [float(location.split('|')[1].split(',')[0]), float(location.split('|')[1].split(',')[1])],
        popup=folium.Popup(location.split('|')[0],parse_html=True),
        icon=folium.Icon(color='green')
    ).add_to(m)  

# mark all the known auctions in Georgia
for location in auctions_georgia_flat:
      folium.Marker(
        [float(location.split('|')[1].split(',')[0]), float(location.split('|')[1].split(',')[1])],
        popup=folium.Popup(location.split('|')[0],parse_html=True),
        icon=folium.Icon(color='blue')
    ).add_to(m)  
        
# mark the geofences
for fence in combo2_agg.fence:
    folium.PolyLine(fence).add_to(m)

m.save('../metadata/test2.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
## visualize with sattelite image

colors = ['white','megenta','yellow','green','blue','purple']
gmap = gmplot2.GoogleMapPlotter(33.909508, -84.355094, 5)

# mark all cluster locations
for location in auctionlike_georgia:
    gmap.marker(location[0], location[1],'red')

# mark all the auctions found via google
for location in auctions_new[:7]: 
    gmap.marker(
        float(location.split('|')[1].split(',')[0]), 
        float(location.split('|')[1].split(',')[1]),
        'green',
        title=location.split('|')[0]
    )
# mark all the known auctions in Georgia
for location in auctions_georgia_flat:
    gmap.marker(
        float(location.split('|')[1].split(',')[0]), 
        float(location.split('|')[1].split(',')[1]),
        'blue',
        title=location.split('|')[0]
    )

# mark the geofences!!
# Polygon
for fence in combo2_agg.fence:
    lats_fence, lons_fence = zip(*fence)
    gmap.plot(lats_fence, lons_fence, 'm', edge_width=10)

# mark the georgia state geofence
lats_fence, lons_fence = zip(*georgia)
gmap.plot(lats_fence, lons_fence, 'm', edge_width=5)

# Generate the heatmap into an HTML file
gmap.draw("../metadata/test2_wsattelite.html")

# %% [markdown]
# ## 8.3: save the geofences

# %%
combo2_agg.to_csv(
    '../metadata/tb_geofence_georgia.csv',
    sep=',',
    index=False
)

# %% [markdown]
# # step 9: import the vinscan data

# %%
scans = pd.read_csv(
    '../../mmr_lookup_profile/metadata/latlong3_frequency_wvar_behavior.csv', 
    header=0, 
    sep=','
)
scans.head(3)
# Out:
#      lat3   long3  scan_mo_1  user_mo_1  vin_mo_1  day_mo_1  scan_mo_2  \
# 0  28.079 -80.616  15         1          14        8         25
# 1  42.017 -80.243  0          0          0         0         0
# 2  38.347 -77.488  42         25         42        8         48
#
#    user_mo_2  vin_mo_2  day_mo_2  scan_mo_3  user_mo_3  vin_mo_3  day_mo_3  \
# 0  2          23        14        40         1          40        18
# 1  0          0         0         0          0          0         0
# 2  24         42        10        67         27         61        10
#
#    scan_mo_6  user_mo_6  vin_mo_6  day_mo_6  scan_mo_12  user_mo_12  \
# 0  148        1          133       54        118         1
# 1  0          0          0         0         1           1
# 2  153        62         147       24        242         85
#
#    vin_mo_12  day_mo_12  scan_mo_all  user_mo_all  vin_mo_all  day_mo_all  \
# 0  116        72         487          4            458         249
# 1  1          1          6            3            6           3
# 2  225        50         1116         270          1024        164
#
#    user_1yr_var  scan_1yr_var  vin_1yr_var
# 0  0.006024      2.392844      1.908762
# 1  0.000000      0.000000      0.000000
# 2  3.326344      19.709959     17.193943

# %% [markdown]
# ## 9.1: filter out locations within the georgia auction geofences
